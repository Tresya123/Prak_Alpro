# %%
#soal 1
#3.1 Menghitung suhu

try:
    suhu = int(input("Masukkan suhu tubuh: "))
    if suhu >= 38:
      print("Anda demam") 
    else:
      print("Anda tidak demam") 
except:
   print("Anda salah memasukan suhu tubuh")


#3.2 Menentukan bilangan positif dan negatif

try:   
    bilangan = int(input("Masukkan suatu bilangan: "))
    if bilangan > 0:
        print("Positif")
    elif bilangan < 0:
        print("Negatif")
    elif bilangan == 0:
        print("Nol")
except :
        print ("anda diminta memasukan angka saja:")  
   

#3.3 Menentukan nilai terbesar
try:
   a = int(input("Masukkan bilangan pertama: "))
   b = int(input("Masukkan bilangan kedua: "))
   c = int(input("Masukkan bilangan ketiga: "))        

   if a > b and a > c:
        print("Terbesar: ", a)
   elif b > a and b > c:
        print("Terbesar: ", b)
   elif c > a and c > b:
        print("Terbesar: ", c)
except: 
   print("Anda salah memasukan input: ")   

#3.3 Ternary Operator
   
   a = int(input("Masukkan bilangan pertama: "))
b = int(input("Masukkan bilangan kedua  : "))
c = int(input("Masukkan bilangan ketiga : "))

terbesar = a if  (a> b and a >c) else b if (b>a and b> c) else c
print("Terbesar = ",terbesar)


#soal 2 Jumlah hari pada bulan

def hari_dalam_bulan(bulan):
    if bulan == 2:
        return 29
    elif bulan in [4,6,9,11]:
        return 30
    else:
        return 31
try:
    no_bulan = int(input("Masukan bulan(1-12) : "))
    if no_bulan < 1 or no_bulan > 12:
        raise ValueError("inputan harus sesuai dengan jumlah bulan")
    
    jumlah_hari_dlm_bulan = hari_dalam_bulan(no_bulan)
    print("Jumlah hari = ",jumlah_hari_dlm_bulan)
except:
    print("Bulan yang diinputkan tidak valid")    

 #soal 3 Mengecek panjang sisi segitiga yang sama
    
    def sisi_sama(sisi1,sisi2,sisi3):
    if sisi1 == sisi2 == sisi3:
        return "3 sisi sama"
    elif sisi1 == sisi2 or sisi1 == sisi3 or sisi2 == sisi3:
        return "2 sisi sama"
    else :
        return "Tidak ada yang sama"
try:
        sisi1 = int(input("Masukan sisi1 = ")) 
        sisi2 = int(input("Masukan sisi2 = ")) 
        sisi3 = int(input("Masukan sisi3 = "))   

        if sisi1 <=0 or sisi2<=0 or sisi3<=0:
             raise ValueError("Panjang sisi tidak valid")
        hasil= sisi_sama(sisi1,sisi2,sisi3)
        print(hasil)
except:
     print("Anda salah memasukan nilai panjang sisi")
